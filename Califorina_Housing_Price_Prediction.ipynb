# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reading the data
data = pd.read_csv("/Users/ibu/Downloads/housing.csv")

# %%
 data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split

X =  data.drop(['median_house_value'],axis = 1)
y = data['median_house_value']

# %%
X_train,X_test, y_train,y_test = train_test_split (X,y,test_size =0.2)

# %%
train_data = X_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11953    -117.45     33.93                20.0       5998.0          1320.0
# 14242    -117.09     32.69                20.0       1102.0           205.0
# 16778    -122.47     37.68                31.0       4077.0           777.0
# 1945     -120.93     38.77                 9.0       2229.0           355.0
# 7969     -118.19     33.87                42.0       1213.0           269.0
# ...          ...       ...                 ...          ...             ...
# 13518    -117.35     34.09                14.0       5983.0          1224.0
# 7115     -118.01     33.91                32.0       2722.0           571.0
# 13134    -121.43     38.46                18.0       1378.0           235.0
# 886      -121.98     37.54                17.0       5133.0          1375.0
# 5324     -118.44     34.05                22.0       3970.0           871.0
#
#        population  households  median_income ocean_proximity  \
# 11953      3185.0      1199.0         3.2731          INLAND
# 14242       852.0       217.0         3.1833      NEAR OCEAN
# 16778      2544.0       738.0         4.5337      NEAR OCEAN
# 1945        788.0       341.0         5.5111          INLAND
# 7969        628.0       229.0         3.6987       <1H OCEAN
# ...           ...         ...            ...             ...
# 13518      3255.0      1150.0         2.5902          INLAND
# 7115       2541.0       462.0         4.2305       <1H OCEAN
# 13134       818.0       262.0         4.0625          INLAND
# 886        3386.0      1339.0         3.1326       <1H OCEAN
# 5324       1588.0       791.0         4.8618       <1H OCEAN
#
#        median_house_value
# 11953            113900.0
# 14242            108300.0
# 16778            306700.0
# 1945             196300.0
# 7969             152100.0
# ...                   ...
# 13518            111500.0
# 7115             221400.0
# 13134            100300.0
# 886              220800.0
# 5324             500001.0
#
# [16346 rows x 10 columns]

# %% [raw]
# train_data.hist(figsize(15,8))

# %%
sns.heatmap(train_data.corr(),annot=True,cmap="YlGnBu")

# %%
train_data.ocean_proximity.value_counts()
# Out:
# <1H OCEAN     7180
# INLAND        5179
# NEAR OCEAN    2159
# NEAR BAY      1824
# ISLAND           4
# Name: ocean_proximity, dtype: int64

# %%
 pd.get_dummies(train_data.ocean_proximity)
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 11953          0       1       0         0           0
# 14242          0       0       0         0           1
# 16778          0       0       0         0           1
# 1945           0       1       0         0           0
# 7969           1       0       0         0           0
# ...          ...     ...     ...       ...         ...
# 13518          0       1       0         0           0
# 7115           1       0       0         0           0
# 13134          0       1       0         0           0
# 886            1       0       0         0           0
# 5324           1       0       0         0           0
#
# [16346 rows x 5 columns]

# %%
train_data = train_data.join( pd.get_dummies(train_data.ocean_proximity)).drop(['ocean_proximity'],axis=1)

# %% [raw]
# train_data

# %%
sns.scatterplot(x="latitude",y="longitude",data=train_data, hue="median_house_value")

# %%
train_data['bedroom_ratio']=train_data['total_bedrooms']/train_data['total_rooms']

# %%
train_data['household_rooms']=train_data['total_rooms']/train_data['households']

# %%
sns.heatmap(train_data.corr(),annot=True,cmap="YlGnBu")

# %%
#Linear_Regression
from sklearn.linear_model import LinearRegression

X_train, y_train=train_data.drop(['median_house_value'],axis=1),train_data['median_house_value']

reg = LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
test_data = X_test.join(y_test)
test_data = test_data.join( pd.get_dummies(test_data.ocean_proximity)).drop(['ocean_proximity'],axis=1)
test_data['bedroom_ratio']=test_data['total_bedrooms']/test_data['total_rooms']
test_data['household_rooms']=test_data['total_rooms']/test_data['households']

# %%
X_test, y_test=test_data.drop(['median_house_value'],axis=1),test_data['median_house_value']

# %%
reg.score(X_test,y_test)
# Out:
# 0.6573877535050503

# %%
#Random_Forest

# %%
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()
forest.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(X_test,y_test)
# Out:
# 0.8172563358669104

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 8777     -118.31     33.79                35.0       2290.0           563.0
# 1971     -120.63     38.68                14.0       1821.0           316.0
# 7734     -118.15     33.93                30.0       3096.0           628.0
# 3127     -118.01     35.12                15.0       1926.0           361.0
# 4334     -118.32     34.08                52.0       2370.0           473.0
# ...          ...       ...                 ...          ...             ...
# 18706    -122.37     40.54                28.0       2213.0           390.0
# 18713    -122.45     40.56                17.0       1712.0           307.0
# 4699     -118.38     34.07                16.0       4814.0          1381.0
# 8128     -118.16     33.79                25.0       5463.0          1265.0
# 11713    -120.15     39.15                25.0       1669.0           348.0
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 8777       1374.0       530.0         3.2472            254700.0          1
# 1971        769.0       266.0         3.0789            131700.0          0
# 7734       1676.0       587.0         4.6583            207300.0          1
# 3127        917.0       316.0         3.3889             68500.0          0
# 4334       1053.0       434.0         4.1429            380300.0          1
# ...           ...         ...            ...                 ...        ...
# 18706      1096.0       378.0         3.6923             86900.0          0
# 18713       963.0       329.0         3.9375            148700.0          0
# 4699       1897.0      1209.0         3.3725            375000.0          1
# 8128       3010.0      1179.0         3.2330            199100.0          0
# 11713       163.0        78.0         5.7500            176600.0          0
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 8777        0       0         0           0       0.245852         4.320755
# 1971        1       0         0           0       0.173531         6.845865
# 7734        0       0         0           0       0.202842         5.274276
# 3127        1       0         0           0       0.187435         6.094937
# 4334        0       0         0           0       0.199578         5.460829
# ...       ...     ...       ...         ...            ...              ...
# 18706       1       0         0           0       0.176231         5.854497
# 18713       1       0         0           0       0.179322         5.203647
# 4699        0       0         0           0       0.286872         3.981803
# 8128        0       0         0           1       0.231558         4.633588
# 11713       1       0         0           0       0.208508        21.397436
#
# [4087 rows x 16 columns]
